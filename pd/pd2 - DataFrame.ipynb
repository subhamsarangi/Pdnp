# %% [markdown]
# # DataFrame - create, view, modify and sort

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser as wb
site='https://en.wikipedia.org/wiki/NFL_win-loss_records'
wb.open(site)
# Out:
# True

# %% [markdown]
# ### Creating a DF by pasting data from the clipboard

# %%
nfl= pd.read_clipboard()
nfl
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         866   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868    AFC Eas

# %% [markdown]
# ## Creating a new DF from a DF

# %%
new_nfl=DataFrame(nfl,columns=['Team','Total Games','Stadium']) # creating a new dataframe from a df
new_nfl
# Out:
#                    Team Total Games  Stadium
# 0        Dallas Cowboys         866      NaN
# 1     Green Bay Packers       1,320      NaN
# 2         Chicago Bears       1,354      NaN
# 3        Miami Dolphins         784      NaN
# 4  New England Patriots         868      NaN

# %% [markdown]
# ## Creating a DF by converting a Dicitonary object

# %%
data = {'City':['SF','LA','NYC'],'Population':[864816,3976000,8538000]}
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [864816, 3976000, 8538000]}

# %%
citydf = DataFrame(data) # Passing a dictionary to create a DF
citydf
# Out:
#   City  Population
# 0   SF      864816
# 1   LA     3976000
# 2  NYC     8538000

# %% [markdown]
# ## Creating a DF by passing a ndarray, DatetimeIndex and Labeled columns

# %%
dates = pd.date_range('20130101', periods=6)
df= DataFrame(np.random.randn(6,4),
             index=dates,
             columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.996086  0.319651 -0.744387 -0.303611
# 2013-01-02  0.994615  0.918780 -0.117987 -0.490556
# 2013-01-03 -1.187591 -1.010861  1.143807  0.390009
# 2013-01-04 -0.532076  0.583875 -0.876323  0.738796
# 2013-01-05  2.078625  1.233413 -1.970443  0.169443
# 2013-01-06  1.085782 -0.671153  1.024663  1.444658

# %% [markdown]
# ## Viewing data

# %%
nfl.tail(2) # the bottom two rows of the df. By default it returns 5 rows
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games  Division
# 3         784  AFC East
# 4         868   AFC Eas

# %%
nfl.head(2) # the top 2 rows. By default it returns 5 rows
# Out:
#    Rank               Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1     Dallas Cowboys  493   367     6  0.573              1960
# 1     2  Green Bay Packers  730   553    37  0.567              1921
#
#   Total Games   Division
# 0         866   NFC East
# 1       1,320  NFC North

# %%
nfl.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
nfl.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
nfl.values
# Out:
# array([[1, 'Dallas Cowboys', 493, 367, 6, 0.573, 1960, '866', 'NFC East'],
#        [2, 'Green Bay Packers', 730, 553, 37, 0.5670000000000001, 1921,
#         '1,320', 'NFC North'],
#        [3, 'Chicago Bears', 744, 568, 42, 0.565, 1920, '1,354', 'NFC North'],
#        [4, 'Miami Dolphins', 439, 341, 4, 0.563, 1966, '784', 'AFC East'],
#        [5, 'New England Patriots', 476, 383, 9, 0.5539999999999999, 1960,
#         '868', 'AFC Eas']], dtype=object)

# %%
nfl.describe()
# Out:
#            Rank         Won        Lost       Tied      Pct.  First NFL Season
# count  5.000000    5.000000    5.000000   5.000000  5.000000           5.00000
# mean   3.000000  576.400000  442.400000  19.600000  0.564400        1945.40000
# std    1.581139  147.984121  108.976144  18.338484  0.006914          22.86482
# min    1.000000  439.000000  341.000000   4.000000  0.554000        1920.00000
# 25%    2.000000  476.000000  367.000000   6.000000  0.563000        1921.00000
# 50%    3.000000  493.000000  383.000000   9.000000  0.565000        1960.00000
# 75%    4.000000  730.000000  553.000000  37.000000  0.567000        1960.00000
# max    5.000000  744.000000  568.000000  42.000000  0.573000        1966.00000

# %%
nfl.T
# Out:
#                                0                  1              2  \
# Rank                           1                  2              3
# Team              Dallas Cowboys  Green Bay Packers  Chicago Bears
# Won                          493                730            744
# Lost                         367                553            568
# Tied                           6                 37             42
# Pct.                       0.573              0.567          0.565
# First NFL Season            1960               1921           1920
# Total Games                  866              1,320          1,354
# Division                NFC East          NFC North      NFC North
#
#                                3                     4
# Rank                           4                     5
# Team              Miami Dolphins  New England Patriots
# Won                          439                   476
# Lost                         341                   383
# Tied                           4                     9
# Pct.                       0.563                 0.554
# First NFL Season            1966                  1960
# Total Games                  784                   868
# Division                AFC East               AFC Eas

# %% [markdown]
# # Adding & Modifying columns

# %% [markdown]
# #### Adding one value to all rows of a column

# %%
nfl['Stadium']="Levi's Stadium"
nfl
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division         Stadium
# 0         866   NFC East  Levi's Stadium
# 1       1,320  NFC North  Levi's Stadium
# 2       1,354  NFC North  Levi's Stadium
# 3         784   AFC East  Levi's Stadium
# 4         868    AFC Eas  Levi's Stadium

# %% [markdown]
# #### Adding a ndarray to rows of a column

# %%
nfl['Stadium']=np.arange(1,6) 
nfl
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division  Stadium
# 0         866   NFC East        1
# 1       1,320  NFC North        2
# 2       1,354  NFC North        3
# 3         784   AFC East        4
# 4         868    AFC Eas        5

# %% [markdown]
# #### Adding Series to a row of columns in a DF

# %%
stadiums=Series(["Levi's Stadium", "AT&T Stadium"], index=[4,0])
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl['Stadium']=stadiums 
nfl
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division         Stadium
# 0         866   NFC East    AT&T Stadium
# 1       1,320  NFC North             NaN
# 2       1,354  NFC North             NaN
# 3         784   AFC East             NaN
# 4         868    AFC Eas  Levi's Stadium

# %% [markdown]
# #### Deleting a column in a DF

# %%
del nfl['Stadium']
nfl
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         866   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868    AFC Eas

# %% [markdown]
# # Sorting

# %%
nfl.sort_index(axis=1, ascending=False) # sorting by axis
# Out:
#    Won Total Games  Tied                  Team  Rank   Pct.  Lost  \
# 0  493         866     6        Dallas Cowboys     1  0.573   367
# 1  730       1,320    37     Green Bay Packers     2  0.567   553
# 2  744       1,354    42         Chicago Bears     3  0.565   568
# 3  439         784     4        Miami Dolphins     4  0.563   341
# 4  476         868     9  New England Patriots     5  0.554   383
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960    AFC Eas

# %%
nfl.sort_values(by='Won',ascending=False) # sorting by values in a row in a columnn
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 4     5  New England Patriots  476   383     9  0.554              1960
# 3     4        Miami Dolphins  439   341     4  0.563              1966
#
#   Total Games   Division
# 2       1,354  NFC North
# 1       1,320  NFC North
# 0         866   NFC East
# 4         868    AFC Eas
# 3         784   AFC East

# %%
ser1= Series(np.random.randn(10))
ser1
# Out:
# 0   -0.556892
# 1    0.542276
# 2    2.067512
# 3    1.409528
# 4    0.926555
# 5    0.165241
# 6    1.803255
# 7   -0.404141
# 8    1.783934
# 9    1.104506
# dtype: float64

# %%
ser1.sort_values()
# Out:
# 0   -0.556892
# 7   -0.404141
# 5    0.165241
# 1    0.542276
# 4    0.926555
# 9    1.104506
# 3    1.409528
# 8    1.783934
# 6    1.803255
# 2    2.067512
# dtype: float64

# %%
ser1.rank() # Rank of the index-values in respect to the data-values
# Out:
# 0     1.0
# 1     4.0
# 2    10.0
# 3     7.0
# 4     5.0
# 5     3.0
# 6     9.0
# 7     2.0
# 8     8.0
# 9     6.0
# dtype: float64
